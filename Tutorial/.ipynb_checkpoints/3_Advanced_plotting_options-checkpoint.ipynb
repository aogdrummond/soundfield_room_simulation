# %% [markdown]
# # Advanced plotting options
#
# The amount of receptors placed along the soundfield may be adapted using the parameter...

# %% [markdown]
# ![receptors_deployed_on_sf.PNG](attachment:receptors_deployed_on_sf.PNG)

# %% [markdown]
# ![soundfield_on_two.PNG](attachment:soundfield_on_two.PNG)

# %% [markdown]
# Testando descrição
#
# ![soundfield_on_boundaries.PNG](attachment:soundfield_on_boundaries.PNG)
